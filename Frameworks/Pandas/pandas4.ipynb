# %%
import pandas as pd
people={
    "first":["Corey","Jane","John"],
    "last":["Schafer","Doe", "Doe"],
    "email":["corey@gmail.com","Jane@gmail.com","john@gmail.com"]
}
df=pd.DataFrame(people)

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe   john@gmail.com

# %%
df['last']=='Doe'
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
filt=((df['last']=='Doe' )&(df['first']=='John'))
filt2=((df['last']=='Schafer' )|(df['first']=='John'))

# %%
df[filt] #
# Out:
#   first last           email
# 2  John  Doe  john@gmail.com

# %%
df.loc[filt]
# Out:
#   first last           email
# 2  John  Doe  john@gmail.com

# %%
df.loc[filt,'email']
# Out:
# 2    john@gmail.com
# Name: email, dtype: object

# %%
#& for and | for or
df.loc[filt2,'email']
# Out:
# 0    corey@gmail.com
# 2     john@gmail.com
# Name: email, dtype: object

# %%
df.loc[~filt,'email']
# Out:
# 0    corey@gmail.com
# 1     Jane@gmail.com
# Name: email, dtype: object

# %%
df=pd.read_csv('data/stackoverflowdata/survey_results_public.csv',index_col='ResponseId')
schema_df=pd.read_csv('data/stackoverflowdata/survey_results_schema.csv',index_col='qname')

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# S1                      QID1
# MainBranch              QID2
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# CompFreq               QID52
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# MiscTech              QID265
# ToolsTech             QID275
# NEWCollabTools        QID274
# ...

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# ...

# %%
#high_salary=(df['CompTotal']>70000)
#countries=['United States of America','India','Austria','Canada','Germany']
country=['India']

# %%
#df.loc[high_salary]
# Out:
#                                                    MainBranch  \
# ResponseId
# 12          I am not primarily a developer, but I write co...
# 15                             I am a developer by profession
# 18                             I am a developer by profession
# 23                             I am a developer by profession
# 26                             I am a developer by profession
# ...                                                       ...
# 73247                          I am a developer by profession
# 73254                          I am a developer by profession
# 73255       I am not primarily a developer, but I write co...
# 73259                          I am a developer by profession
# 73265                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 12          Employed, full-time;Independent contractor, fr...
# 15          Employed, full-time;Independent contractor, fr...
# ...

# %%
df.loc[high_salary,['Country','Currency','LanguageHaveWorkedWith','CompTotal']]
# Out:
#                              Country                   Currency  \
# ResponseId
# 12          United States of America  USD\tUnited States dollar
# 15          United States of America  USD\tUnited States dollar
# 18                           Austria          EUR European Euro
# 23                            Canada       CAD\tCanadian dollar
# 26                           Germany          EUR European Euro
# ...                              ...                        ...
# 73247             Russian Federation         RUB\tRussian ruble
# 73254                      Australia     AUD\tAustralian dollar
# 73255       United States of America  USD\tUnited States dollar
# 73259                          India          INR\tIndian rupee
# 73265       United States of America  USD\tUnited States dollar
#
#                                        LanguageHaveWorkedWith  CompTotal
# ResponseId
# 12          C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL   194400.0
# ...

# %%
filt=df['Country'].isin(countries)
#filt

df.loc[filt,['Country','Currency','LanguageHaveWorkedWith','CompTotal']]
# Out:
#                              Country                   Currency  \
# ResponseId
# 2                             Canada       CAD\tCanadian dollar
# 5           United States of America  USD\tUnited States dollar
# 6                            Germany                        NaN
# 7                              India                        NaN
# 8                              India                        NaN
# ...                              ...                        ...
# 73259                          India          INR\tIndian rupee
# 73263                        Germany                        NaN
# 73265       United States of America  USD\tUnited States dollar
# 73266       United States of America  USD\tUnited States dollar
# 73268                         Canada                        NaN
#
#                                    LanguageHaveWorkedWith  CompTotal
# ResponseId
# 2                                   JavaScript;TypeScript        NaN
# ...

# %%
filt2=df['Country'].isin(country)
result=df.loc[filt2,['CompTotal','LanguageHaveWorkedWith']]

# %%
result.head(45)
# Out:
#              CompTotal                             LanguageHaveWorkedWith
# ResponseId
# 7                  NaN      C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 8                  NaN                 C;C++;HTML/CSS;Java;JavaScript;SQL
# 66                 NaN                                                 C#
# 141                NaN              HTML/CSS;JavaScript;Kotlin;TypeScript
# 152           100000.0     Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL
# 163                NaN                                  Bash/Shell;Python
# 170                NaN                                     Assembly;C;C++
# 180                NaN                                       Go;Java;Ruby
# 197          4500000.0                             Python;Rust;TypeScript
# 292                NaN    C++;HTML/CSS;Java;JavaScript;PHP;SQL;TypeScript
# 302                NaN                                               Dart
# ...

# %%
df['LanguageHaveWorkedWith']
# Out:
# ResponseId
# 1                                                      NaN
# 2                                    JavaScript;TypeScript
# 3                        C#;C++;HTML/CSS;JavaScript;Python
# 4                             C#;JavaScript;SQL;TypeScript
# 5              C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#                                ...
# 73264    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73265            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73266                   HTML/CSS;JavaScript;PHP;Python;SQL
# 73267                                        C#;Delphi;VBA
# 73268          C#;JavaScript;Lua;PowerShell;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: object

# %%
filt=df['LanguageHaveWorkedWith'].str.contains('Python',na=False)

# %%
df.loc[filt,['CompTotal','LanguageHaveWorkedWith']].head(40)
# Out:
#             CompTotal                             LanguageHaveWorkedWith
# ResponseId
# 3             32000.0                  C#;C++;HTML/CSS;JavaScript;Python
# 7                 NaN      C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 12           194400.0  C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 15           110000.0        HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 17            37000.0                               C#;Java;PHP;Python;R
# 18           190000.0                                         Python;SQL
# 20                NaN                C++;HTML/CSS;Java;JavaScript;Python
# 22            32000.0                              Python;SQL;TypeScript
# 33                NaN                                         C++;Python
# 34                NaN                                      C++;Go;Python
# 35            30000.0          HTML/CSS;JavaScript;Python;SQL;TypeScript
# 36                NaN                                      MATLAB;Python
# ...
