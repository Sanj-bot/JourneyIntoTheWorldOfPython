# %%
import pandas as pd
import numpy as np
people={
    "first":["Corey","Jane","John"],
    "last":["Schafer","Doe", "Doe"],
    "email":["corey@gmail.com","Jane@gmail.com","john@gmail.com"]
}
df=pd.DataFrame(people)

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe   john@gmail.com

# %%
df.sort_values(by='last',ascending=False)
# Out:
#    first     last            email
# 0  Corey  Schafer  corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe   john@gmail.com

# %%
df.sort_values(by=['last','first'],ascending=True) #sort on last name then first name
# Out:
#    first     last            email
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe   john@gmail.com
# 0  Corey  Schafer  corey@gmail.com

# %%
df.sort_values(by=['last','first'],ascending=[False,True],inplace=True)

# %%
df
# Out:
#    first     last            email
# 0  Corey  Schafer  corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe   john@gmail.com

# %%
df.sort_index()
# Out:
#    first     last            email
# 0  Corey  Schafer  corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Doe   john@gmail.com

# %%
df['last'].sort_values()
# Out:
# 1        Doe
# 2        Doe
# 0    Schafer
# Name: last, dtype: object

# %%
import pandas as pd
df=pd.read_csv('data/survey_results_public.csv')
schema_df=pd.read_csv('data/survey_results_schema.csv')

# %%
df.sort_values(by='Country',inplace=True)

# %%
df['Country'].head(100)
# Out:
# 39018    Afghanistan
# 62723    Afghanistan
# 85185    Afghanistan
# 50437    Afghanistan
# 88340    Afghanistan
#             ...
# 38869        Albania
# 70187        Albania
# 27476        Albania
# 46829        Albania
# 24964        Albania
# Name: Country, Length: 100, dtype: object

# %%
df.sort_values(by=['Country','LanguageWantToWorkWith'],ascending=[True,False],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15388\398607256.py in ?()
# ----> 1 df.sort_values(by=['Country','LanguageWantToWorkWith'],ascending=[True,False],inplace=True)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7155                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    7156                 f" != length of by ({len(by)})"
#    7157             )
#    7158         if len(by) > 1:
# -> 7159             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    7160
#    7161             # need to rewrap columns in Series to apply key function
#    7162             if key is not None:
#
# ...

# %%
df[['Country','LanguageWantToWorkWith']].head(50) #note: 2 square brackets]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df[['Country','LanguageWantToWorkWith']].head(50) #note: 2 square brackets]]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Age'].nlargest(30)
# Out:
# 34757    99.0
# 11279    99.0
# 16126    99.0
# 43862    99.0
# 25147    99.0
# 78072    99.0
# 57808    99.0
# 27680    99.0
# 29707    99.0
# 69840    99.0
# 61847    99.0
# 9792     99.0
# 83561    99.0
# 36089    99.0
# 11495    99.0
# 87858    99.0
# 20086    99.0
# 83085    99.0
# 50517    99.0
# 42514    99.0
# 49804    99.0
# 56579    98.9
# 75382    98.0
# 77992    98.0
# 21287    98.0
# 5461     97.0
# 64464    95.0
# 87686    95.0
# 63800    94.0
# 56511    91.0
# Name: Age, dtype: float64

# %%
df.nlargest(10,'Age')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 34757       34973  I used to be a developer by profession, but no...       No
# 11279       11332                     I am a developer by profession       No
# 16126       16214  I am not primarily a developer, but I write co...      Yes
# 43862       44142                     I am a developer by profession      Yes
# 25147       25294                        I code primarily as a hobby      Yes
# 78072       78562             I am a student who is learning to code      Yes
# 57808       58176  I am not primarily a developer, but I write co...       No
# 27680       27841                     I am a developer by profession      Yes
# 29707       29884                     I am a developer by profession      Yes
# 69840       70284             I am a student who is learning to code       No
#
#                                              OpenSourcer  \
# ...

# %%
df.nlargest(10,'Age')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 34757       34973  I used to be a developer by profession, but no...       No
# 11279       11332                     I am a developer by profession       No
# 16126       16214  I am not primarily a developer, but I write co...      Yes
# 43862       44142                     I am a developer by profession      Yes
# 25147       25294                        I code primarily as a hobby      Yes
# 78072       78562             I am a student who is learning to code      Yes
# 57808       58176  I am not primarily a developer, but I write co...       No
# 27680       27841                     I am a developer by profession      Yes
# 29707       29884                     I am a developer by profession      Yes
# 69840       70284             I am a student who is learning to code       No
#
#                                              OpenSourcer  \
# ...
