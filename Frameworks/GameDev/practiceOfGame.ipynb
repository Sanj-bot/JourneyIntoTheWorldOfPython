# %%
import pygame, sys,os
from pygame.locals import *
x=200
y=100
z=2
red=[x,y,z]
pygame.init()
#set up window using display.set_mode()
window=pygame.display.set_mode((500,500))


#drawing surface
screen=pygame.display.get_surface()
screen.fill(red)
x=x+1
y=y+10
z=z+40
pygame.display.flip()

while True:
    #main game loop
    for event in pygame.event.get():
        print(event)
        if event.type==QUIT:
            pygame.quit()
            sys.exit(0)
    pygame.display
# Out:
# <Event(4352-AudioDeviceAdded {'which': 0, 'iscapture': 0})>
# <Event(4352-AudioDeviceAdded {'which': 0, 'iscapture': 1})>
# <Event(32774-WindowShown {'window': None})>
# <Event(32768-ActiveEvent {'gain': 1, 'state': 2})>
# <Event(32785-WindowFocusGained {'window': None})>
# <Event(770-TextEditing {'text': '', 'start': 0, 'length': 0, 'window': None})>
# <Event(32768-ActiveEvent {'gain': 1, 'state': 1})>
# <Event(32783-WindowEnter {'window': None})>
# <Event(1024-MouseMotion {'pos': (310, 412), 'rel': (0, 0), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(32770-VideoExpose {})>
# <Event(32776-WindowExposed {'window': None})>
# <Event(768-KeyDown {'unicode': '', 'key': 1073742048, 'mod': 4160, 'scancode': 224, 'window': None})>
# <Event(768-KeyDown {'unicode': '\x04', 'key': 100, 'mod': 4160, 'scancode': 7, 'window': None})>
# <Event(769-KeyUp {'unicode': '\x04', 'key': 100, 'mod': 4160, 'scancode': 7, 'window': None})>
# <Event(769-KeyUp {'unicode': '', 'key': 1073742048, 'mod': 4096, 'scancode': 224, 'window': None})>
# <Event(768-KeyDown {'unicode': '', 'key': 1073742048, 'mod': 4160, 'scancode': 224, 'window': None})>
# <Event(768-KeyDown {'unicode': '\x04', 'key': 100, 'mod': 4160, 'scancode': 7, 'window': None})>
# <Event(769-KeyUp {'unicode': '\x04', 'key': 100, 'mod': 4160, 'scancode': 7, 'window': None})>
# <Event(769-KeyUp {'unicode': '', 'key': 1073742048, 'mod': 4096, 'scancode': 224, 'window': None})>
# <Event(1025-MouseButtonDown {'pos': (310, 412), 'button': 1, 'touch': False, 'window': None})>
# <Event(1026-MouseButtonUp {'pos': (310, 412), 'button': 1, 'touch': False, 'window': None})>
# <Event(768-KeyDown {'unicode': '', 'key': 1073742048, 'mod': 4160, 'scancode': 224, 'window': None})>
# <Event(768-KeyDown {'unicode': '\x04', 'key': 100, 'mod': 4160, 'scancode': 7, 'window': None})>
# <Event(769-KeyUp {'unicode': '\x04', 'key': 100, 'mod': 4160, 'scancode': 7, 'window': None})>
# <Event(769-KeyUp {'unicode': '', 'key': 1073742048, 'mod': 4096, 'scancode': 224, 'window': None})>
# <Event(1024-MouseMotion {'pos': (309, 413), 'rel': (-1, 1), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (309, 415), 'rel': (0, 2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (309, 416), 'rel': (0, 1), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (309, 418), 'rel': (0, 2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (310, 423), 'rel': (1, 5), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (312, 428), 'rel': (2, 5), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (314, 432), 'rel': (2, 4), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (317, 436), 'rel': (3, 4), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (321, 438), 'rel': (4, 2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (325, 444), 'rel': (4, 6), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (328, 448), 'rel': (3, 4), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (332, 450), 'rel': (4, 2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (334, 454), 'rel': (2, 4), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (336, 458), 'rel': (2, 4), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (339, 462), 'rel': (3, 4), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (341, 464), 'rel': (2, 2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (342, 468), 'rel': (1, 4), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (343, 471), 'rel': (1, 3), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (344, 473), 'rel': (1, 2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (345, 475), 'rel': (1, 2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (346, 475), 'rel': (1, 0), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (347, 475), 'rel': (1, 0), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (347, 473), 'rel': (0, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (350, 470), 'rel': (3, -3), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (354, 462), 'rel': (4, -8), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (360, 452), 'rel': (6, -10), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (366, 439), 'rel': (6, -13), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (372, 419), 'rel': (6, -20), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (376, 399), 'rel': (4, -20), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (380, 381), 'rel': (4, -18), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (385, 361), 'rel': (5, -20), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (386, 339), 'rel': (1, -22), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (388, 320), 'rel': (2, -19), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (388, 305), 'rel': (0, -15), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (389, 289), 'rel': (1, -16), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (390, 271), 'rel': (1, -18), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (393, 251), 'rel': (3, -20), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (397, 237), 'rel': (4, -14), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (402, 223), 'rel': (5, -14), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (405, 211), 'rel': (3, -12), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (409, 200), 'rel': (4, -11), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (411, 193), 'rel': (2, -7), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (412, 187), 'rel': (1, -6), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (414, 182), 'rel': (2, -5), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (416, 177), 'rel': (2, -5), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (417, 173), 'rel': (1, -4), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (417, 172), 'rel': (0, -1), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (418, 171), 'rel': (1, -1), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (418, 170), 'rel': (0, -1), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (418, 168), 'rel': (0, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (418, 166), 'rel': (0, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (418, 164), 'rel': (0, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (418, 162), 'rel': (0, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (419, 162), 'rel': (1, 0), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (419, 160), 'rel': (0, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (420, 160), 'rel': (1, 0), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (421, 158), 'rel': (1, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (422, 155), 'rel': (1, -3), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (423, 152), 'rel': (1, -3), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (424, 148), 'rel': (1, -4), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (426, 142), 'rel': (2, -6), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (427, 133), 'rel': (1, -9), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (428, 122), 'rel': (1, -11), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (428, 109), 'rel': (0, -13), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (428, 96), 'rel': (0, -13), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (426, 85), 'rel': (-2, -11), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (423, 76), 'rel': (-3, -9), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (421, 66), 'rel': (-2, -10), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (421, 60), 'rel': (0, -6), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (421, 54), 'rel': (0, -6), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (421, 45), 'rel': (0, -9), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (421, 40), 'rel': (0, -5), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (421, 37), 'rel': (0, -3), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (421, 36), 'rel': (0, -1), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (421, 35), 'rel': (0, -1), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (421, 33), 'rel': (0, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (421, 32), 'rel': (0, -1), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (421, 30), 'rel': (0, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (422, 29), 'rel': (1, -1), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (422, 27), 'rel': (0, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (422, 26), 'rel': (0, -1), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (422, 24), 'rel': (0, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (423, 23), 'rel': (1, -1), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (423, 21), 'rel': (0, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (424, 21), 'rel': (1, 0), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (424, 19), 'rel': (0, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (424, 17), 'rel': (0, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (426, 15), 'rel': (2, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (426, 12), 'rel': (0, -3), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (427, 9), 'rel': (1, -3), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (428, 7), 'rel': (1, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (430, 3), 'rel': (2, -4), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (432, 1), 'rel': (2, -2), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(1024-MouseMotion {'pos': (434, 0), 'rel': (2, -3), 'buttons': (0, 0, 0), 'touch': False, 'window': None})>
# <Event(32768-ActiveEvent {'gain': 0, 'state': 1})>
# <Event(32784-WindowLeave {'window': None})>
# <Event(32787-WindowClose {'window': None})>
# <Event(256-Quit {})>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
import pygame, sys,os
from pygame.locals import *
catx=10
caty=10
screen=0


def myquit():
    pygame.quit()
    sys.exit(0)

def check_inputs(events):
    global catx,caty,screen
    '''function to handle events particularly quitting the program'''
    for event in events:
        if event.type=QUIT:
            quit()
    screen.fill((0,0,0))
    pygame.draw.rect(screen,(255,255,255),(catx,50,50,10))
    pygame.display
