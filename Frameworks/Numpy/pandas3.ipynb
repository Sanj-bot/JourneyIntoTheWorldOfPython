# %%
people={
    "first":["Corey","Jane","John"],
    "last":["Schafer","Doe", "Poe"],
    "email":["corey@gmail.com","Jane@gmail.com","john@gmail.com"]
}
import pandas as pd
df=pd.DataFrame(people)
df
# Out:
#    first     last            email
# 0  Corey  Schafer  corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Poe   john@gmail.com

# %%
df['email']
#email made index
df.set_index('email')
# Out:
#                  first     last
# email
# corey@gmail.com  Corey  Schafer
# Jane@gmail.com    Jane      Doe
# john@gmail.com    John      Poe

# %%
df #index is still numerical
# Out:
#    first     last            email
# 0  Corey  Schafer  corey@gmail.com
# 1   Jane      Doe   Jane@gmail.com
# 2   John      Poe   john@gmail.com

# %%
df.set_index('email',inplace=True)

# %%
df
# Out:
#                  first     last
# email
# corey@gmail.com  Corey  Schafer
# Jane@gmail.com    Jane      Doe
# john@gmail.com    John      Poe

# %%
df.index
# Out:
# Index(['corey@gmail.com', 'Jane@gmail.com', 'john@gmail.com'], dtype='object', name='email')

# %%
df.loc['corey@gmail.com','last']
# Out:
# 'Schafer'

# %%
df.iloc[0]
# Out:
# first      Corey
# last     Schafer
# Name: corey@gmail.com, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#              email  first     last
# 0  corey@gmail.com  Corey  Schafer
# 1   Jane@gmail.com   Jane      Doe
# 2   john@gmail.com   John      Poe

# %%
df=pd.read_csv('data/stackoverflowdata/survey_results_public.csv',index_col='ResponseId')

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
schema_df=pd.read_csv('data/stackoverflowdata/survey_results_schema.csv',index_col='qid')
schema_df
# Out:
#               qname                                           question  \
# qid
# QID16            S0  <div><span style="font-size:19px;"><strong>Hel...
# QID12      MetaInfo                                  Browser Meta Info
# QID1             S1  <span style="font-size:22px; font-family: aria...
# QID2     MainBranch  Which of the following options best describes ...
# QID296   Employment  Which of the following best describes your cur...
# ...             ...                                                ...
# QID290  Frequency_2  Interacting with people outside of your immedi...
# QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# QID294  TrueFalse_2  Do you use learning resources provided by your...
# QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#        force_resp  type selector
# qid
# QID16       False    DB       TB
# QID12       False  Meta  Browser
# ...

# %%
schema_df.loc['QID2','question']
# Out:
# 'Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code." <b>*</b>'

# %%
#index sorted alpahbetically
schema_df.sort_index()
# Out:
#               qname                                           question  \
# qid
# QID1             S1  <span style="font-size:22px; font-family: aria...
# QID100  SOVisitFreq  How frequently would you say you visit Stack O...
# QID101    SOAccount              Do you have a Stack Overflow account?
# QID102   SOPartFreq  How frequently would you say you participate i...
# QID106       SOComm  Do you consider yourself a member of the Stack...
# ...             ...                                                ...
# QID52      CompFreq   Is that compensation weekly, monthly, or yearly?
# QID6        Country  Where do you live? <span style="font-weight: b...
# QID61            S3  <span style="font-size:22px; font-family: aria...
# QID71         OpSys  What is the primary <b>operating system</b> in...
# QID91            S4  <span style="font-size:22px; font-family: aria...
#
#        force_resp    type selector
# qid
# QID1        False      DB       TB
# ...
